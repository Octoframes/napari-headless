# %%
# import sample data
from skimage.data import cells3d
import matplotlib.pyplot as plt

import napari

viewer = napari.Viewer(show=False)
viewer.add_image(cells3d(), name='cells')
img = viewer.screenshot(canvas_only=False, flash=False)                                       

plt.imshow(img)
# Out:
# 2023-10-26 15:02:26.708 Python[6346:252297] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/c3/3bzrl3qx043bknt1ycn3fcym0000gn/T/org.python.python.savedState
